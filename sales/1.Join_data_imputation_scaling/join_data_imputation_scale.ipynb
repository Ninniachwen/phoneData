# %% [markdown]
# # Load data sets

# %% [markdown]
# ## Data set w/ technical specs

# %%
import pandas as pd
df1 = pd.read_csv("C:\\Users\\Jessica Tran\\Downloads\\2017_2024_GSM_scaled_final.csv")

df1 = df1[['approx_price_eur_scale', 'battery_mah_scale','ram_in_gb_scale','internal_memory_in_gb_scale','model','brand','id']]
df1.shape
# Out:
# (9931, 7)

# %% [markdown]
# ### Convert to appropriate data type

# %%
df1.dtypes
# Out:
# approx_price_eur_scale         float64
# battery_mah_scale              float64
# ram_in_gb_scale                float64
# internal_memory_in_gb_scale    float64
# model                           object
# brand                           object
# id                              object
# dtype: object

# %%
df1[df1.select_dtypes(include=['object']).columns] = df1.select_dtypes(include=['object']).astype('category')
#df1.head()

# %%
df1.dtypes
# Out:
# approx_price_eur_scale          float64
# battery_mah_scale               float64
# ram_in_gb_scale                 float64
# internal_memory_in_gb_scale     float64
# model                          category
# brand                          category
# id                             category
# dtype: object

# %% [markdown]
# ## Sales Data

# %%
df2 = pd.read_csv("C:\\Users\\Jessica Tran\\OneDrive\\Dokumenter\\GitHub\\phoneData\\sales\\0.Raw_data\\top 120 best-selling mobile phones.csv")
df2 = df2[['Manufacturer', 'Model','Units Sold (million )','Rank', 'Year']]
df2.shape
# Out:
# (120, 5)

# %% [markdown]
# ### Convert to appropriate data type

# %%
df2.dtypes
# Out:
# Manufacturer              object
# Model                     object
# Units Sold (million )    float64
# Rank                       int64
# Year                       int64
# dtype: object

# %%
df2[df2.select_dtypes(include=['object']).columns] = df2.select_dtypes(include=['object']).astype('category')

# %%
df2.dtypes
# Out:
# Manufacturer             category
# Model                    category
# Units Sold (million )     float64
# Rank                        int64
# Year                        int64
# dtype: object

# %% [markdown]
# # Join datasets

# %% [markdown]
# Since joining the datasets are performed differently for phones before and after 2017 the process is split in two.

# %% [markdown]
# ## Phone models before and in 2017

# %%
# Keep rows where 'Year' is less than or equal to 2017
df2_before = df2[df2['Year'] <= 2017].copy()

len(df2_before['Year'].unique())
(df2_before)
# Out:
#     Manufacturer                Model  Units Sold (million )  Rank  Year
# 0          Nokia                 1100                  250.0     1  2003
# 1          Nokia                 1110                  247.5     2  2005
# 2          Apple    iPhone 6 & 6 Plus                  222.4     3  2014
# 3          Nokia           105 Series                  200.0     4  2013
# 4          Apple  iPhone 6S & 6S Plus                  174.1     5  2015
# ..           ...                  ...                    ...   ...   ...
# 112        Nokia               N-Gage                    3.0   113  2003
# 113           LG                   G2                    3.0   114  2013
# 114         LeTV          LeEco Le 1s                    3.0   115  2016
# 118       Google     Pixel & Pixel XL                    2.1   119  2016
# 119         Palm               Centro                    2.0   120  2007
#
# [78 rows x 5 columns]

# %% [markdown]
# ### Modify model names to align with df1

# %%
df2_before['Model'] = df2_before['Model'].str.replace(r'^(Cookie)\((KP500)\)$', r'\2 \1', regex=True)
df2_before['Model'] = df2_before['Model'].str.replace(r'(Star/Tocco Lite) \((S5230)\)', r'\2 Star', regex=True)
df2_before['Model'] = df2_before['Model'].str.replace(r'^(Viewty)\((KU990)\)$', r'\2 \1', regex=True)

# Replace Samsung Star/Tocco Lite (S5230) with S5230 Star
df2_before['Model'] = df2_before['Model'].str.replace(r'^(.*) \((S5230)\)$', r'\2 \1', regex=True)

# Lowercase 's' for iPhone models
df2_before['Model'] = df2_before['Model'].str.replace(r'(iPhone \d+)(S)', r'\1s', regex=True)

# Add space in iPhone models and RAZR models
df2_before['Model'] = df2_before['Model'].str.replace(r'(iPhone)(\d+)', r'\1 \2', regex=True)
df2_before['Model'] = df2_before['Model'].str.replace(r'(RAZR)(\d+)', r'RAZR \2', regex=True)

# Add 'I9505' for 'Galaxy S4'
df2_before['Model'] = df2_before['Model'].str.replace(r'(^Galaxy S4$)', r'I9505 \1', regex=True)

# Add 'N7100' to 'Galaxy Note II'
df2_before['Model'] = df2_before['Model'].str.replace(r'^(Galaxy Note II)$', r'\1 N7100', regex=True)

# Add '4G' to 'ThunderBolt'
df2_before['Model'] = df2_before['Model'].str.replace(r'^(ThunderBolt)$', r'\1 4G', regex=True)

# Uppercase 'Droid Bionic' and add 'XT875'
df2_before['Model'] = df2_before['Model'].str.replace(r'^(Droid Bionic)$', lambda x: x.group(0).upper() + ' XT875', regex=True)

# Remove 'LeEco' from 'LeEco Le 1s'
df2_before['Model'] = df2_before['Model'].str.replace(r'^(LeEco) ', '', regex=True)
df2_before['Model'] = df2_before['Model'].str.replace(r'^(StarTAC)$', r'\1 75', regex=True)


# Display unique model names after all changes
(df2_before['Model'].unique())
# Out:
# array(['1100', '1110', 'iPhone 6 & 6 Plus', '105 Series',
#        'iPhone 6s & 6S Plus', 'iPhone 5s', '3210', 'iPhone 7 & 7 Plus',
#        '6600', '1200', '5230', 'E1100', 'iPhone 5',
#        '2600(2610/2626/2630)', 'RAZRV3', '1600(1650/1661)', '3310(3330)',
#        'iPhone 8 & 8 Plus', '1208(1209)', '1280', '6010(6020/6030)',
#        'Galaxy S III & Galaxy S III Mini', 'I9505 Galaxy S4',
#        '5130(5220/5310)', 'iPhone X', 'iPhone 4s', 'StarTAC 75', 'C200',
#        'C139', 'Galaxy S7 & Galaxy S7 edge', '3100(3120)', '6230(6233)',
#        'iPhone 4', '6300', 'Galaxy S6 & Galaxy S6 edge', 'N70(N72/N73)',
#        'Galaxy S8 & Galaxy S8+', 'Galaxy S II', '2650', 'iPhone 3GS',
#        'E250', 'KP100', 'Galaxy Note II N7100', '5200(5300)', 'Galaxy S',
#        'Galaxy Grand Prime Plus', 'Chocolate VX8500', '2100',
#        'Mate 10 & Mate 10 Pro', 'ThunderBolt 4G', 'Mate 9',
#        '5610 XpressMusic', '5800 XpressMusic', 'E71', 'K300(K310)',
#        'K750', 'W800(W810)', 'BlackBerry Pearl', 'DROID BIONIC XT875',
#        'KP500 Cookie', 'SGH-E700', 'N95', 'Shine', 'S5230 Star',
#        'Galaxy Note', 'Mi 2', 'Galaxy Note 3', 'G3', 'Galaxy Note 8',
#        'F1 Plus', 'iPhone', 'KU990 Viewty', 'Samsung Galaxy J9+',
#        'N-Gage', 'G2', 'Le 1s', 'Pixel & Pixel XL', 'Centro'],
#       dtype=object)

# %% [markdown]
# ### Exact matching by Model between the two datasets

# %%
common_values = pd.merge(df1[['model']], df2_before[['Model']], left_on='model', right_on='Model')['model'].unique()
print(len(common_values))
# Out:
# 46

# %%
df2_filtered = df2_before[df2_before['Model'].isin(common_values)]
df1_filtered = df1[df1['model'].isin(common_values)]

df_before_merged = pd.merge(df2_filtered[['Model','Units Sold (million )','Manufacturer','Year']], df1_filtered, 
                       left_on=['Model', 'Manufacturer'], right_on=['model', 'brand'], how='inner')
df_before_merged
# Out:
#                       Model  Units Sold (million )   Manufacturer  Year  \
# 0                      1100                  250.0          Nokia  2003
# 1                      1110                  247.5          Nokia  2005
# 2                 iPhone 5s                  164.5          Apple  2013
# 3                      3210                  161.0          Nokia  1999
# 4                      6600                  150.0          Nokia  2003
# 5                      1200                  150.0          Nokia  2007
# 6                      5230                  150.0          Nokia  2009
# 7                     E1100                  150.0        Samsung  2009
# 8                  iPhone 5                  146.2          Apple  2012
# 9                      1280                  100.0          Nokia  2010
# 10          I9505 Galaxy S4                   70.0        Samsung  2013
# 11                 iPhone X                   63.0          Apple  2017
# 12                iPhone 4s                   60.0          Apple  2011
# 13               StarTAC 75                   60.0       Motorola  1996
# 14                     C200                   60.0       Motorola  2003
# 15                     C139                   60.0       Motorola  2005
# 16                 iPhone 4                   50.0          Apple  2010
# 17                     6300                   47.0          Nokia  2006
# 18                     2650                   35.0          Nokia  2004
# 19               iPhone 3GS                   35.0          Apple  2009
# 20                     E250                   30.0        Samsung  2006
# 21                    KP100                   30.0             LG  2008
# 22     Galaxy Note II N7100                   30.0        Samsung  2012
# 23  Galaxy Grand Prime Plus                   24.2        Samsung  2016
# 24                     2100                   20.0          Nokia  2003
# 25           ThunderBolt 4G                   16.0            HTC  2011
# 26                   Mate 9                   15.8         Huawei  2016
# 27         5610 XpressMusic                   15.0          Nokia  2007
# 28         5800 XpressMusic                   15.0          Nokia  2008
# 29                      E71                   15.0          Nokia  2008
# 30                     K750                   15.0  Sony Ericsson  2005
# 31       DROID BIONIC XT875                   13.0       Motorola  2011
# 32             KP500 Cookie                   13.0             LG  2009
# 33                      N95                   10.0          Nokia  2007
# 34               S5230 Star                   10.0        Samsung  2009
# 35                     Mi 2                   10.0         Xiaomi  2012
# 36            Galaxy Note 3                   10.0        Samsung  2013
# 37                       G3                   10.0             LG  2014
# 38                  F1 Plus                    7.0           Oppo  2016
# 39                   iPhone                    6.0          Apple  2007
# 40             KU990 Viewty                    5.0             LG  2007
# 41                   N-Gage                    3.0          Nokia  2003
# 42                       G2                    3.0             LG  2013
# 43                   Centro                    2.0           Palm  2007
#
#     approx_price_eur_scale  battery_mah_scale  ram_in_gb_scale  \
# 0                      NaN           0.316401              NaN
# 1                -0.322661           0.135943              NaN
# 2                 0.355742          -0.422488         0.059124
# 3                      NaN                NaN              NaN
# 4                      NaN           0.316401              NaN
# 5                -0.910545          -0.894430              NaN
# 6                -0.169966           1.079920        -0.772848
# 7                -0.279908          -1.124388              NaN
# 8                 1.853732          -0.210500         0.651283
# 9                -0.317296          -0.818520              NaN
# 10                0.355742           0.719267         1.238497
# 11                0.304572          -0.427139        -0.050487
# 12                0.417847           0.085471        -0.054181
# 13                     NaN          -0.437476              NaN
# 14                     NaN          -0.675550              NaN
# 15               -0.322661           0.229237              NaN
# 16                0.285147           0.720524        -0.023633
# 17               -0.556570          -0.259850              NaN
# 18                     NaN          -0.351388              NaN
# 19               -0.060024           1.389297         0.317697
# 20               -0.371315          -0.663574              NaN
# 21               -0.288676          -0.329266              NaN
# 22                1.461168           1.554399         2.855543
# 23               -0.686284          -0.275506         0.515041
# 24                     NaN          -0.543290              NaN
# 25                0.711558           0.047917        -0.036347
# 26                2.087849           1.111402         0.303262
# 27               -0.202594          -0.101205              NaN
# 28               -0.086883           1.277883        -0.069196
# 29               -0.131726           1.966661        -0.069196
# 30               -0.146380           0.135943              NaN
# 31                0.564702           0.441063        -0.054181
# 32               -0.243833          -0.329266              NaN
# 33                0.682344           0.097102        -0.672800
# 34               -0.206613          -0.157586              NaN
# 35                0.970462           0.384887         2.855543
# 36                0.574899           1.377972         2.417871
# 37                0.223277           0.746108         0.762073
# 38                0.502630          -0.027844         0.303262
# 39                2.540715           1.881860              NaN
# 40               -0.291088           0.295408              NaN
# 41                     NaN           0.316401              NaN
# 42                0.209638           1.158404         1.238497
# 43               -0.221412           0.627370              NaN
#
#     internal_memory_in_gb_scale                    model          brand  \
# 0                           NaN                     1100          Nokia
# 1                     -0.147863                     1110          Nokia
# 2                      4.269950                iPhone 5s          Apple
# 3                           NaN                     3210          Nokia
# 4                     -0.405369                     6600          Nokia
# 5                     -0.209452                     1200          Nokia
# 6                     -0.260051                     5230          Nokia
# 7                     -0.275858                    E1100        Samsung
# 8                      4.664849                 iPhone 5          Apple
# 9                           NaN                     1280          Nokia
# 10                     4.269950          I9505 Galaxy S4        Samsung
# 11                     0.752890                 iPhone X          Apple
# 12                     5.414197                iPhone 4s          Apple
# 13                          NaN               StarTAC 75       Motorola
# 14                          NaN                     C200       Motorola
# 15                          NaN                     C139       Motorola
# 16                     6.764993                 iPhone 4          Apple
# 17                    -0.206505                     6300          Nokia
# 18                          NaN                     2650          Nokia
# 19                     7.259932               iPhone 3GS          Apple
# 20                    -0.178736                     E250        Samsung
# 21                    -0.149998                    KP100             LG
# 22                     4.664849     Galaxy Note II N7100        Samsung
# 23                    -0.582151  Galaxy Grand Prime Plus        Samsung
# 24                          NaN                     2100          Nokia
# 25                    -0.081574           ThunderBolt 4G            HTC
# 26                     1.202017                   Mate 9         Huawei
# 27                    -0.197663         5610 XpressMusic          Nokia
# 28                    -0.134112         5800 XpressMusic          Nokia
# 29                    -0.128354                      E71          Nokia
# 30                    -0.084535                     K750  Sony Ericsson
# 31                     1.017580       DROID BIONIC XT875       Motorola
# 32                    -0.140665             KP500 Cookie             LG
# 33                    -0.094513                      N95          Nokia
# 34                    -0.264633               S5230 Star        Samsung
# 35                     2.022969                     Mi 2         Xiaomi
# 36                     4.269950            Galaxy Note 3        Samsung
# 37                     0.441166                       G3             LG
# 38                     1.202017                  F1 Plus           Oppo
# 39                    11.906273                   iPhone          Apple
# 40                    -0.138720             KU990 Viewty             LG
# 41                    -0.514512                   N-Gage          Nokia
# 42                     1.794084                       G2             LG
# 43                    -0.137488                   Centro           Palm
#
#                                  id
# 0                        Nokia 1100
# 1                        Nokia 1110
# 2                   Apple iPhone 5s
# 3                        Nokia 3210
# 4                        Nokia 6600
# 5                        Nokia 1200
# 6                        Nokia 5230
# 7                     Samsung E1100
# 8                    Apple iPhone 5
# 9                        Nokia 1280
# 10          Samsung I9505 Galaxy S4
# 11                   Apple iPhone X
# 12                  Apple iPhone 4s
# 13              Motorola StarTAC 75
# 14                    Motorola C200
# 15                    Motorola C139
# 16                   Apple iPhone 4
# 17                       Nokia 6300
# 18                       Nokia 2650
# 19                 Apple iPhone 3GS
# 20                     Samsung E250
# 21                         LG KP100
# 22     Samsung Galaxy Note II N7100
# 23  Samsung Galaxy Grand Prime Plus
# 24                       Nokia 2100
# 25               HTC ThunderBolt 4G
# 26                    Huawei Mate 9
# 27           Nokia 5610 XpressMusic
# 28           Nokia 5800 XpressMusic
# 29                        Nokia E71
# 30               Sony Ericsson K750
# 31      Motorola DROID BIONIC XT875
# 32                  LG KP500 Cookie
# 33                        Nokia N95
# 34               Samsung S5230 Star
# 35                      Xiaomi Mi 2
# 36            Samsung Galaxy Note 3
# 37                            LG G3
# 38                     Oppo F1 Plus
# 39                     Apple iPhone
# 40                  LG KU990 Viewty
# 41                     Nokia N-Gage
# 42                            LG G2
# 43                      Palm Centro

# %% [markdown]
# df_before_merged is the dataframe that contains the phones found in both data sets for phone before and in 2017.

# %% [markdown]
# ## Phone models after 2017

# %%
# Keep rows where 'Year' is greater than 2017
df2_after = df2[df2['Year'] > 2017].copy()

# reset index
df2_after.reset_index(drop=True, inplace=True)

# Display the first few rows to verify
(df2_after)
# Out:
#    Manufacturer                                       Model  \
# 0         Apple                 iPhone11, 11Pro & 11Pro Max
# 1         Apple        iPhone XR, iPhone XS & iPhone XS Max
# 2         Apple     iPhone 12, 12 mini ,12 Pro & 12 Pro Max
# 3       Samsung       Galaxy S10, Galaxy S10+ & Galaxy S10e
# 4       Samsung                      Galaxy S9 & Galaxy S9+
# 5        Huawei                     P20, P20 Pro & P20 Lite
# 6       Samsung                                  Galaxy A10
# 7        Xiaomi             Redmi Note 8 & Redmi Note 8 Pro
# 8         Apple                           iPhone 12 Pro Max
# 9       Samsung  Galaxy S20, Galaxy S20+ & Galaxy S20 Ultra
# 10      Samsung                                  Galaxy A50
# 11        Apple                    iPhone SE 2nd generation
# 12      Samsung                                  Galaxy A51
# 13      Samsung                                  Galaxy A20
# 14       Xiaomi             Redmi Note 7 & Redmi Note 7 Pro
# 15       Huawei                               P30 & P30 Pro
# 16      Samsung                                 Galaxy A21s
# 17       Huawei                       Mate 20 & Mate 20 Pro
# 18      Samsung                                  Galaxy A01
# 19      Samsung                                  Galaxy A11
# 20      Samsung                              Galaxy J2 Core
# 21       Xiaomi                             Redmi Note9 Pro
# 22      Samsung  Galaxy S21, Galaxy S21+ & Galaxy S21 Ultra
# 23       Huawei                       Mate 30 & Mate 30 Pro
# 24      Samsung                            Galaxy S22 Ultra
# 25       Xiaomi                                    Redmi 6A
# 26      Samsung                               Galaxy S20 FE
# 27         Oppo                                          A5
# 28      Samsung                               Galaxy Note 9
# 29      Samsung                                  Galaxy A30
# 30       Xiaomi                                    Redmi 8A
# 31       Xiaomi                                     Redmi 8
# 32      Samsung                                  Galaxy J4+
# 33      Samsung                                  Galaxy J6+
# 34      Samsung                    Samsung Galaxy S24 Ultra
# 35      Samsung                       Samsung Galaxy 414 4G
# 36      Samsung                                 Galaxy A10s
# 37      Samsung                       Samsung Galaxy S23 FE
# 38      Samsung                                 Galaxy A30s
# 39      Samsung                          Samsung Galaxy A55
# 40      Samsung                          Samsung Galaxy S24
# 41      Samsung                       Samsung Galaxy A15 4G
#
#     Units Sold (million )  Rank  Year
# 0                   159.2     9  2019
# 1                   151.1    10  2018
# 2                   100.0    21  2020
# 3                    37.0    42  2019
# 4                    35.4    43  2018
# 5                    32.0    46  2018
# 6                    30.3    47  2019
# 7                    30.0    52  2019
# 8                    29.0    53  2020
# 9                    28.0    54  2020
# 10                   24.2    57  2019
# 11                   24.2    58  2020
# 12                   23.2    59  2019
# 13                   23.1    60  2019
# 14                   20.0    63  2019
# 15                   20.0    64  2019
# 16                   19.4    65  2020
# 17                   17.0    67  2018
# 18                   16.9    68  2019
# 19                   15.3    71  2020
# 20                   15.2    72  2018
# 21                   15.0    80  2020
# 22                   13.5    81  2021
# 23                   12.0    84  2019
# 24                   10.9    85  2022
# 25                   10.0    95  2019
# 26                   10.0    96  2020
# 27                    9.7    97  2019
# 28                    9.6    98  2018
# 29                    9.2    99  2019
# 30                    7.3   100  2019
# 31                    6.8   102  2019
# 32                    6.4   103  2018
# 33                    4.9   106  2018
# 34                    4.9   107  2024
# 35                    4.0   109  2023
# 36                    3.9   110  2019
# 37                    3.8   111  2023
# 38                    3.4   112  2019
# 39                    2.7   116  2024
# 40                    2.4   117  2024
# 41                    2.2   118  2023

# %% [markdown]
# ### Join Model and Manufacturer, and use RegEx to align with df1['id']

# %%
import re

# Apply additional regex replacements
df2_after['Model'] = df2_after['Model'].apply(lambda part: re.sub(r'(\d)(?=Pro)', r'\1 ', part))  # Add space before 'Pro'
df2_after['Model'] = df2_after['Model'].apply(lambda part: re.sub(r'(Note)(\d)', r'\1 \2', part))  # Add space between 'Note' and number
df2_after['Model'] = df2_after['Model'].apply(lambda part: re.sub(r'(iPhone)(\d)', r'\1 \2', part))  # Add space after 'iPhone'

# %%
import re

df2_after['id'] = df2_after.apply(
    lambda row: row['Manufacturer'] + ' ' + re.sub(rf'^{row["Manufacturer"]}\s*', '', row['Model'], flags=re.IGNORECASE), 
    axis=1
)

# %%
# Use regex to add '5G' only to the specified models
df2_after['id'] = df2_after['id'].str.replace(
    r'^(Samsung Galaxy S21(?:\+| Ultra)?|Samsung Galaxy S22 Ultra)$',
    r'\1 5G', regex=True)

# %% [markdown]
# ### Exact matching

# %%
common_values = pd.merge(df1[['id']], df2_after[['id']], left_on='id', right_on='id')['id'].unique()
print(len(common_values))
# Out:
# 25

# %%
df2_filtered = df2_after[df2_after['id'].isin(common_values)]
df1_filtered = df1[df1['id'].isin(common_values)]

df_after_merged = pd.merge(df2_filtered[['Units Sold (million )','id','Year']], df1_filtered.drop(['model', 'brand'], axis=1), 
                       left_on=['id'], right_on=['id'], how='inner')
df_after_merged
# Out:
#     Units Sold (million )                           id  Year  \
# 0                    30.3           Samsung Galaxy A10  2019
# 1                    29.0      Apple iPhone 12 Pro Max  2020
# 2                    24.2           Samsung Galaxy A50  2019
# 3                    23.2           Samsung Galaxy A51  2019
# 4                    23.1           Samsung Galaxy A20  2019
# 5                    19.4          Samsung Galaxy A21s  2020
# 6                    16.9           Samsung Galaxy A01  2019
# 7                    15.3           Samsung Galaxy A11  2020
# 8                    15.2       Samsung Galaxy J2 Core  2018
# 9                    15.0      Xiaomi Redmi Note 9 Pro  2020
# 10                   10.9  Samsung Galaxy S22 Ultra 5G  2022
# 11                   10.0              Xiaomi Redmi 6A  2019
# 12                   10.0        Samsung Galaxy S20 FE  2020
# 13                    9.7                      Oppo A5  2019
# 14                    9.2           Samsung Galaxy A30  2019
# 15                    7.3              Xiaomi Redmi 8A  2019
# 16                    6.8               Xiaomi Redmi 8  2019
# 17                    6.4           Samsung Galaxy J4+  2018
# 18                    4.9           Samsung Galaxy J6+  2018
# 19                    4.9     Samsung Galaxy S24 Ultra  2024
# 20                    3.9          Samsung Galaxy A10s  2019
# 21                    3.8        Samsung Galaxy S23 FE  2023
# 22                    3.4          Samsung Galaxy A30s  2019
# 23                    2.7           Samsung Galaxy A55  2024
# 24                    2.4           Samsung Galaxy S24  2024
#
#     approx_price_eur_scale  battery_mah_scale  ram_in_gb_scale  \
# 0                -0.736397          -0.295214        -0.948828
# 1                 0.475788          -0.661448         0.264498
# 2                 0.083795           0.221625        -0.136165
# 3                -0.099001           0.221625        -0.136165
# 4                -0.451113           0.221625        -0.542497
# 5                -0.431267           0.768138        -0.978546
# 6                -0.655452          -1.409450        -1.392895
# 7                -0.514019          -0.320656        -1.392895
# 8                -0.927901          -0.817617        -1.385318
# 9                -0.289513           0.789914         0.264498
# 10               -0.010106           0.180955         0.366450
# 11               -0.972200          -0.367455        -0.786597
# 12                0.164063           0.223741         0.264498
# 13               -0.352002           1.016793              NaN
# 14               -0.272810           0.221625        -0.542497
# 15               -0.775695           1.083022        -0.948828
# 16               -0.764926           1.083022        -0.542497
# 17               -0.529202          -0.029833        -0.786597
# 18               -0.307702          -0.029833        -0.187877
# 19                0.476019          -0.202063         0.408114
# 20               -0.561660           0.221625        -0.948828
# 21               -0.132891          -0.559350        -0.078946
# 22               -0.395482           0.221625        -0.542497
# 23               -0.813792          -0.202063        -1.255736
# 24               -0.298376          -1.664553        -0.701119
#
#     internal_memory_in_gb_scale
# 0                     -0.667524
# 1                      0.397905
# 2                     -0.180109
# 3                     -0.180109
# 4                     -0.667524
# 5                     -1.003751
# 6                     -1.237360
# 7                     -1.003751
# 8                     -1.060132
# 9                     -0.536532
# 10                    -0.157614
# 11                    -0.816841
# 12                     0.397905
# 13                          NaN
# 14                    -0.667524
# 15                    -0.667524
# 16                    -0.667524
# 17                    -0.816841
# 18                    -0.330258
# 19                     0.123973
# 20                    -0.667524
# 21                    -0.485727
# 22                    -0.667524
# 23                    -0.925027
# 24                    -0.925027

# %% [markdown]
# # Merged dataframes from before and after 2017 into one dataframe

# %% [markdown]
# Include only relevant columns

# %%
df_before_merged = df_before_merged.drop(['Model','Manufacturer','model', 'brand'], axis=1)
df_before_merged.shape
# Out:
# (44, 7)

# %%
df_combined = pd.concat([df_before_merged, df_after_merged], ignore_index=True)

# %%
df_combined = df_combined.rename(columns={'Units Sold (million )': 'sales'})

# %%
df_combined
# Out:
#     sales  Year  approx_price_eur_scale  battery_mah_scale  ram_in_gb_scale  \
# 0   250.0  2003                     NaN           0.316401              NaN
# 1   247.5  2005               -0.322661           0.135943              NaN
# 2   164.5  2013                0.355742          -0.422488         0.059124
# 3   161.0  1999                     NaN                NaN              NaN
# 4   150.0  2003                     NaN           0.316401              NaN
# ..    ...   ...                     ...                ...              ...
# 64    3.9  2019               -0.561660           0.221625        -0.948828
# 65    3.8  2023               -0.132891          -0.559350        -0.078946
# 66    3.4  2019               -0.395482           0.221625        -0.542497
# 67    2.7  2024               -0.813792          -0.202063        -1.255736
# 68    2.4  2024               -0.298376          -1.664553        -0.701119
#
#     internal_memory_in_gb_scale                     id
# 0                           NaN             Nokia 1100
# 1                     -0.147863             Nokia 1110
# 2                      4.269950        Apple iPhone 5s
# 3                           NaN             Nokia 3210
# 4                     -0.405369             Nokia 6600
# ..                          ...                    ...
# 64                    -0.667524    Samsung Galaxy A10s
# 65                    -0.485727  Samsung Galaxy S23 FE
# 66                    -0.667524    Samsung Galaxy A30s
# 67                    -0.925027     Samsung Galaxy A55
# 68                    -0.925027     Samsung Galaxy S24
#
# [69 rows x 7 columns]

# %% [markdown]
# # Handle missing values

# %%
df_combined.isna().sum()
# Out:
# sales                           0
# Year                            0
# approx_price_eur_scale          8
# battery_mah_scale               1
# ram_in_gb_scale                24
# internal_memory_in_gb_scale     9
# id                              0
# dtype: int64

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

def preprocess_data(df, numerical_columns, categorical_columns, n_neighbors=3):
    """
    Preprocesses a DataFrame by imputing missing numerical values and keeping categorical columns unchanged.
    
    Parameters:
        df (pd.DataFrame): The input DataFrame.
        numerical_columns (list): List of numerical columns to be imputed.
        categorical_columns (list): List of categorical columns to be passed through.
        n_neighbors (int): Number of neighbors for KNN imputation (default=3).
    
    Returns:
        pd.DataFrame: Transformed DataFrame with imputed numerical columns and unchanged categorical columns.
    """
    # Define the KNN imputer for numerical data
    numerical_imputer = KNNImputer(n_neighbors=n_neighbors)

    # Define the column transformer
    preprocessor = ColumnTransformer(
        transformers=[
            ('numerical', numerical_imputer, numerical_columns),
            ('categorical', 'passthrough', categorical_columns)
        ]
    )

    # Apply transformations
    transformed_data = preprocessor.fit_transform(df)

    # Convert back to a DataFrame
    transformed_df = pd.DataFrame(transformed_data, columns=numerical_columns + categorical_columns)

    return transformed_df

# %%
# Define column lists
numerical_columns = ['approx_price_eur_scale', 'battery_mah_scale', 'ram_in_gb_scale',
                     'internal_memory_in_gb_scale', 'sales']
categorical_columns = ['Year', 'id']

# Call the function
df_imputed = preprocess_data(df_combined, numerical_columns, categorical_columns)

df_imputed
# Out:
#    approx_price_eur_scale battery_mah_scale ram_in_gb_scale  \
# 0               -0.045628          0.316401       -0.020814
# 1               -0.322661          0.135943       -0.020814
# 2                0.355742         -0.422488        0.059124
# 3               -0.031377         -0.155652       -0.020814
# 4               -0.453473          0.316401       -0.020814
# ..                    ...               ...             ...
# 64               -0.56166          0.221625       -0.948828
# 65              -0.132891          -0.55935       -0.078946
# 66              -0.395482          0.221625       -0.542497
# 67              -0.813792         -0.202063       -1.255736
# 68              -0.298376         -1.664553       -0.701119
#
#    internal_memory_in_gb_scale  sales  Year                     id
# 0                     1.238906  250.0  2003             Nokia 1100
# 1                    -0.147863  247.5  2005             Nokia 1110
# 2                      4.26995  164.5  2013        Apple iPhone 5s
# 3                      1.24468  161.0  1999             Nokia 3210
# 4                    -0.405369  150.0  2003             Nokia 6600
# ..                         ...    ...   ...                    ...
# 64                   -0.667524    3.9  2019    Samsung Galaxy A10s
# 65                   -0.485727    3.8  2023  Samsung Galaxy S23 FE
# 66                   -0.667524    3.4  2019    Samsung Galaxy A30s
# 67                   -0.925027    2.7  2024     Samsung Galaxy A55
# 68                   -0.925027    2.4  2024     Samsung Galaxy S24
#
# [69 rows x 7 columns]

# %%
df_imputed.isna().sum()
# Out:
# approx_price_eur_scale         0
# battery_mah_scale              0
# ram_in_gb_scale                0
# internal_memory_in_gb_scale    0
# sales                          0
# Year                           0
# id                             0
# dtype: int64

# %% [markdown]
# # Scale sales column

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd

def scale_group(group):
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(group[numerical_cols])
    scaled_cols = [col + '_scale' for col in numerical_cols]
    scaled_df = pd.DataFrame(scaled_data, columns=scaled_cols, index=group.index)
    for orig_col, scaled_col in zip(numerical_cols, scaled_cols):
        
        # Insert scaled columns right after the original columns
        col_idx = group.columns.get_loc(orig_col)
        group.insert(col_idx + 1, scaled_col, scaled_df[scaled_col])
    return group

# %%
# Copy the dataframe for safety
df = df_imputed.copy(deep=True)

# Define the column to scale
numerical_cols = ['sales']
group_col = 'Year'

# Apply scaling to each group by the specified column
df_transformed = df.groupby(group_col, group_keys=False).apply(scale_group)

# Sort by 'year' and other identifiers if needed
df_transformed = df_transformed.sort_values(['Year', 'id'])

# remove sales
df_transformed = df_transformed.drop('sales', axis=1)

(df_transformed)
# Out:
#    approx_price_eur_scale battery_mah_scale ram_in_gb_scale  \
# 13               0.133253         -0.437476        0.377943
# 3               -0.031377         -0.155652       -0.020814
# 14               0.133253          -0.67555        0.377943
# 0               -0.045628          0.316401       -0.020814
# 24              -0.512611          -0.54329       -0.971313
# ..                    ...               ...             ...
# 54              -0.010106          0.180955         0.36645
# 65              -0.132891          -0.55935       -0.078946
# 67              -0.813792         -0.202063       -1.255736
# 68              -0.298376         -1.664553       -0.701119
# 63               0.476019         -0.202063        0.408114
#
#    internal_memory_in_gb_scale  sales_scale  Year                           id
# 13                    3.479012     0.000000  1996          Motorola StarTAC 75
# 3                      1.24468     0.000000  1999                   Nokia 3210
# 14                    3.479012    -0.397680  2003                Motorola C200
# 0                     1.238906     1.666777  2003                   Nokia 1100
# 24                   -0.969545    -0.832302  2003                   Nokia 2100
# ..                         ...          ...   ...                          ...
# 54                   -0.157614     0.000000  2022  Samsung Galaxy S22 Ultra 5G
# 65                   -0.485727     0.000000  2023        Samsung Galaxy S23 FE
# 67                   -0.925027    -0.568241  2024           Samsung Galaxy A55
# 68                   -0.925027    -0.837408  2024           Samsung Galaxy S24
# 63                    0.123973     1.405649  2024     Samsung Galaxy S24 Ultra
#
# [69 rows x 7 columns]

# %% [markdown]
# # Save the final DataFrame to a CSV file

# %%
# Save the final DataFrame to a CSV file
df_transformed.to_csv('../2.Hierarchical_clustering/df_transformed.csv', index=False)
